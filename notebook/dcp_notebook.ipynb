# %% [markdown]
# ## Data Cleaning Pipeline (Kaggle->Client-Ready)

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading CSV into Notebook

# %%
df = pd.read_csv("../data/raw_data.csv")
